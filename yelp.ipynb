# %%
import argparse
import json
import pprint
import requests
import sys
import urllib
from urllib.error import HTTPError
from urllib.parse import quote
from urllib.parse import urlencode

# %%
# Constants for accessing the API
API_KEY = open('yelp_api.txt', 'r').readlines()[1][:-1] # api stored in seperate .txt file
API_HOST = 'https://api.yelp.com'
SEARCH_PATH = '/v3/businesses/search'
BUSINESS_PATH = '/v3/businesses/'

### Search Terms
params = {
    'term': 'coffee',
    'location': 'Clinton Hill, Brooklyn',
    'limit':'50'
}

# %%
def request(host=API_HOST, path=SEARCH_PATH, api_key=API_KEY, url_params=params):
    """Given your API_KEY, send a GET request to the API.
    Args:
        host (str): The domain host of the API.
        path (str): The path of the API after the domain.
        API_KEY (str): Your API Key.
        url_params (dict): An optional set of query parameters in the request.
    Returns:
        dict: The JSON response from the request.
    Raises:
        HTTPError: An error occurs from the HTTP request.
    """
    url_params = url_params or {}
    url = '{0}{1}'.format(host, quote(path.encode('utf8')))
    headers = {
        'Authorization': 'Bearer %s' % api_key,
    }

    print(u'Querying {0} ...'.format(url))

    response = requests.request('GET', url, headers=headers, params=url_params)

    return response.json()

# %%
# Enter what you want to search for here. For a full list of searchable params, see https://www.yelp.com/developers/documentation/v3/business_search
coffee = request()
# Out:
# Querying https://api.yelp.com/v3/businesses/search ...

# %%
for i in range(len(coffee['businesses'])):
    item = coffee['businesses'][i] #['alias']
    
    print(' Store Name:',item['name'], '\n',
          'Categories:', [item['categories'][i]['title'] for i in range(len(item['categories']))], '\n',
          'Latitude:', item['coordinates']['latitude'], '\n',
          'Longitude:', item['coordinates']['longitude'], '\n',
          'City:', item['location']['city'], '\n',
          'Zip Code:', item['location']['zip_code'], '\n',
          #'Price:', item['price'],  '\n',
          'Rating:', item['rating'], '\n',
          'Review Count:', item['review_count'], '\n')
# Out:
#  Store Name: BKG Coffee Roasters
#  Categories: ['Coffee & Tea']
#  Latitude: 40.694125
#  Longitude: -73.961949
#  City: Brooklyn
#  Zip Code: 11205
#  Rating: 4.5
#  Review Count: 54
#
#  Store Name: Urban Vintage
#  Categories: ['Coffee & Tea']
#  Latitude: 40.6879410741655
#  Longitude: -73.9628667682618
#  City: Brooklyn
#  Zip Code: 11238
#  Rating: 4.5
#  Review Count: 248
#
#  Store Name: The Good Batch
#  Categories: ['Bakeries', 'Coffee & Tea', 'Ice Cream & Frozen Yogurt']
#  Latitude: 40.68254
#  Longitude: -73.96331
#  City: Brooklyn
#  Zip Code: 11238
#  Rating: 4.0
#  Review Count: 134
#
#  Store Name: The Market
#  Categories: ['Coffee & Tea', 'Asian Fusion', 'American (New)']
#  Latitude: 40.6887759766071
#  Longitude: -73.9604237030468
#  City: Clinton Hill
#  Zip Code: 11238
#  Rating: 4.0
#  Review Count: 116
#
#  Store Name: Outpost Café
#  Categories: ['Coffee & Tea', 'Cafes', 'Bars']
#  Latitude: 40.6818428039551
#  Longitude: -73.9602966308594
#  City: Brooklyn
#  Zip Code: 11238
#  Rating: 4.0
#  Review Count: 342
#
#  Store Name: Kitten Espresso Bar
#  Categories: ['Coffee & Tea', 'Cafes', 'Bakeries']
#  Latitude: 40.68817
#  Longitude: -73.95734
#  City: Brooklyn
#  Zip Code: 11238
#  Rating: 4.5
#  Review Count: 17
#
#  Store Name: Bedford Hill
#  Categories: ['Coffee & Tea', 'Bars', 'Breakfast & Brunch']
#  Latitude: 40.68763
#  Longitude: -73.9568199
#  City: Brooklyn
#  Zip Code: 11238
#  Rating: 3.5
#  Review Count: 181
#
#  Store Name: Stonefruit Espresso + Kitchen
#  Categories: ['Cafes', 'Salad', 'Bakeries']
#  Latitude: 40.68878
#  Longitude: -73.95528
#  City: Bedford-Stuyvesant
#  Zip Code: 11205
#  Rating: 4.0
#  Review Count: 105
#
#  Store Name: Primrose Cafe
#  Categories: ['Cafes']
#  Latitude: 40.6868401
#  Longitude: -73.9662323
#  City: Brooklyn
#  Zip Code: 11238
#  Rating: 3.0
#  Review Count: 98
#
#  Store Name: Playground Coffee Shop
#  Categories: ['Art Galleries', 'Venues & Event Spaces', 'Coffee & Tea']
#  Latitude: 40.6865747
#  Longitude: -73.9548484
#  City: Brooklyn
#  Zip Code: 11216
#  Rating: 4.0
#  Review Count: 23
#
#  Store Name: Clementine Bakery
#  Categories: ['Bakeries', 'Vegan', 'Cupcakes']
#  Latitude: 40.68756
#  Longitude: -73.9596
#  City: Brooklyn
#  Zip Code: 11238
#  Rating: 4.0
#  Review Count: 358
#
#  Store Name: Daily Press Coffee
#  Categories: ['Coffee & Tea', 'Wine Bars']
#  Latitude: 40.6814904
#  Longitude: -73.9555811
#  City: Brooklyn
#  Zip Code: 11238
#  Rating: 3.5
#  Review Count: 145
#
#  Store Name: Brooklyn Kolache
#  Categories: ['Coffee & Tea', 'Bakeries', 'Cafes']
#  Latitude: 40.6907913077698
#  Longitude: -73.9556479454041
#  City: Brooklyn
#  Zip Code: 11205
#  Rating: 4.5
#  Review Count: 258
#
#  Store Name: Beny's Delice
#  Categories: ['Coffee & Tea', 'Bakeries', 'Sandwiches']
#  Latitude: 40.6836638
#  Longitude: -73.9671519
#  City: Brooklyn
#  Zip Code: 11238
#  Rating: 4.0
#  Review Count: 103
#
#  Store Name: Peck's
#  Categories: ['Specialty Food', 'Bakeries', 'Coffee & Tea']
#  Latitude: 40.693489
#  Longitude: -73.967376
#  City: New York
#  Zip Code: 11205
#  Rating: 4.0
#  Review Count: 104
#
#  Store Name: Mike's Coffee Shop
#  Categories: ['Diners', 'Coffee & Tea', 'Breakfast & Brunch']
#  Latitude: 40.689673412113
#  Longitude: -73.9653054186587
#  City: Brooklyn
#  Zip Code: 11205
#  Rating: 4.0
#  Review Count: 173
#
#  Store Name: Brooklyn Roasting Company
#  Categories: ['Coffee & Tea']
#  Latitude: 40.704228
#  Longitude: -73.986241
#  City: Brooklyn
#  Zip Code: 11201
#  Rating: 4.0
#  Review Count: 425
#
#  Store Name: Hungry Ghost
#  Categories: ['Coffee & Tea', 'Bakeries', 'Sandwiches']
#  Latitude: 40.6860872
#  Longitude: -73.9735729
#  City: Brooklyn
#  Zip Code: 11217
#  Rating: 4.0
#  Review Count: 128
#
#  Store Name: Café 232
#  Categories: ['Cafes', 'Korean']
#  Latitude: 40.6909146742084
#  Longitude: -73.9595839827104
#  City: Brooklyn
#  Zip Code: 11205
#  Rating: 5.0
#  Review Count: 1
#
#  Store Name: Parlor Coffee
#  Categories: ['Coffee & Tea']
#  Latitude: 40.69748
#  Longitude: -73.97041
#  City: Brooklyn
#  Zip Code: 11205
#  Rating: 4.5
#  Review Count: 8
#
#  Store Name: Kitten Coffee
#  Categories: ['Coffee Roasteries', 'Adult Education']
#  Latitude: 40.6924749165773
#  Longitude: -73.9566235989332
#  City: Brooklyn
#  Zip Code: 11205
#  Rating: 5.0
#  Review Count: 11
#
#  Store Name: Seven Point Espresso
#  Categories: ['Coffee & Tea', 'Breakfast & Brunch', 'Vegetarian']
#  Latitude: 40.67834
#  Longitude: -73.96363
#  City: Brooklyn
#  Zip Code: 11238
#  Rating: 4.0
#  Review Count: 74
#
#  Store Name: Seven Twenty Four Coffee Shop and Cafe
#  Categories: ['Cafes', 'Coffee & Tea', 'Waffles']
#  Latitude: 40.69464
#  Longitude: -73.95414
#  City: Brooklyn
#  Zip Code: 11205
#  Rating: 4.5
#  Review Count: 10
#
#  Store Name: dot & line
#  Categories: ['Coffee & Tea', 'Cafes']
#  Latitude: 40.68416
#  Longitude: -73.98357
#  City: Brooklyn
#  Zip Code: 11217
#  Rating: 4.5
#  Review Count: 28
#
#  Store Name: Dough
#  Categories: ['Donuts']
#  Latitude: 40.6890699083996
#  Longitude: -73.9570917731448
#  City: Brooklyn
#  Zip Code: 11205
#  Rating: 4.5
#  Review Count: 1613
#
#  Store Name: Absolute Coffee
#  Categories: ['Coffee & Tea', 'Bakeries']
#  Latitude: 40.68818
#  Longitude: -73.98762
#  City: Brooklyn
#  Zip Code: 11201
#  Rating: 4.5
#  Review Count: 139
#
#  Store Name: Little Roy Coffee Co.
#  Categories: ['Coffee & Tea']
#  Latitude: 40.68864
#  Longitude: -73.94741
#  City: Brooklyn
#  Zip Code: 11216
#  Rating: 4.5
#  Review Count: 21
#
#  Store Name: Cafe con Libros
#  Categories: ['Themed Cafes', 'Coffee & Tea']
#  Latitude: 40.674261
#  Longitude: -73.952563
#  City: Brooklyn
#  Zip Code: 11216
#  Rating: 5.0
#  Review Count: 7
#
#  Store Name: Choice Market
#  Categories: ['Bakeries', 'Breakfast & Brunch', 'Burgers']
#  Latitude: 40.6884159690869
#  Longitude: -73.9629691917761
#  City: Brooklyn
#  Zip Code: 11238
#  Rating: 3.5
#  Review Count: 370
#
#  Store Name: Burly Coffee
#  Categories: ['Coffee & Tea']
#  Latitude: 40.6920973
#  Longitude: -73.9427741
#  City: Brooklyn
#  Zip Code: 11221
#  Rating: 4.5
#  Review Count: 73
#
#  Store Name: Mekelburg's
#  Categories: ['Specialty Food', 'American (New)', 'Bars']
#  Latitude: 40.6875419616699
#  Longitude: -73.9623336791992
#  City: Brooklyn
#  Zip Code: 11238
#  Rating: 4.5
#  Review Count: 191
#
#  Store Name: Nostrand Cafe
#  Categories: ['Korean', 'Cafes', 'Breakfast & Brunch']
#  Latitude: 40.68978
#  Longitude: -73.95114
#  City: Bedford-Stuyvesant
#  Zip Code: 11216
#  Rating: 4.5
#  Review Count: 73
#
#  Store Name: The Civil Service Cafe
#  Categories: ['Coffee & Tea', 'Breakfast & Brunch', 'Bars']
#  Latitude: 40.6891442
#  Longitude: -73.9512606
#  City: Brooklyn
#  Zip Code: 11216
#  Rating: 4.0
#  Review Count: 126
#
#  Store Name: Bushwick Grind
#  Categories: ['Coffee & Tea']
#  Latitude: 40.70172
#  Longitude: -73.94452
#  City: Brooklyn
#  Zip Code: 11206
#  Rating: 5.0
#  Review Count: 63
#
#  Store Name: Bittersweet
#  Categories: ['Coffee & Tea', 'Donuts', 'Cafes']
#  Latitude: 40.689498
#  Longitude: -73.9725219
#  City: Brooklyn
#  Zip Code: 11205
#  Rating: 3.5
#  Review Count: 105
#
#  Store Name: Brooklyn Roasting Company
#  Categories: ['Coffee & Tea']
#  Latitude: 40.6975976
#  Longitude: -73.9680088
#  City: Brooklyn
#  Zip Code: 11205
#  Rating: 3.5
#  Review Count: 56
#
#  Store Name: Sit & Wonder
#  Categories: ['Coffee & Tea', 'Sandwiches', 'Salad']
#  Latitude: 40.677513627085
#  Longitude: -73.963737487793
#  City: Brooklyn
#  Zip Code: 11238
#  Rating: 4.0
#  Review Count: 209
#
#  Store Name: Safra coffee
#  Categories: ['Coffee & Tea']
#  Latitude: 40.678344
#  Longitude: -73.962131
#  City: Brooklyn
#  Zip Code: 11238
#  Rating: 5.0
#  Review Count: 3
#
#  Store Name: Lunitas
#  Categories: ['Cafes', 'American (New)', 'Breakfast & Brunch']
#  Latitude: 40.68232
#  Longitude: -73.9603
#  City: Brooklyn
#  Zip Code: 11238
#  Rating: 4.5
#  Review Count: 147
#
#  Store Name: Willoughby General
#  Categories: ['Coffee & Tea', 'Specialty Food', 'Gift Shops']
#  Latitude: 40.6938502192497
#  Longitude: -73.9488619565964
#  City: Brooklyn
#  Zip Code: 11206
#  Rating: 4.5
#  Review Count: 23
#
#  Store Name: Furman's Coffee
#  Categories: ['Coffee & Tea']
#  Latitude: 40.678798
#  Longitude: -73.949595
#  City: Brooklyn
#  Zip Code: 11216
#  Rating: 4.5
#  Review Count: 24
#
#  Store Name: Evodio's Place
#  Categories: ['Cafes', 'Mexican', 'American (Traditional)']
#  Latitude: 40.6913531760712
#  Longitude: -73.9687436216104
#  City: New York
#  Zip Code: 11205
#  Rating: 5.0
#  Review Count: 2
#
#  Store Name: Penny House Cafe
#  Categories: ['Coffee & Tea', 'Breakfast & Brunch', 'Sandwiches']
#  Latitude: 40.676044
#  Longitude: -73.963713
#  City: Brooklyn
#  Zip Code: 11238
#  Rating: 4.5
#  Review Count: 199
#
#  Store Name: Marcy & Myrtle Cafe
#  Categories: ['Coffee & Tea', 'Breakfast & Brunch']
#  Latitude: 40.6951266257375
#  Longitude: -73.9492401651453
#  City: Bedford-Stuyvesant
#  Zip Code: 11206
#  Rating: 4.5
#  Review Count: 48
#
#  Store Name: Anchor Coffee and Corp
#  Categories: ['Coffee & Tea']
#  Latitude: 40.6842654
#  Longitude: -73.9411785
#  City: Brooklyn
#  Zip Code: 11221
#  Rating: 4.5
#  Review Count: 60
#
#  Store Name: Four & Twenty Blackbirds
#  Categories: ['Bakeries', 'Coffee & Tea']
#  Latitude: 40.68023
#  Longitude: -73.96938
#  City: Brooklyn
#  Zip Code: 11238
#  Rating: 4.0
#  Review Count: 31
#
#  Store Name: Maison May Vanderbilt
#  Categories: ['Cafes', 'Breakfast & Brunch']
#  Latitude: 40.68922
#  Longitude: -73.96921
#  City: Brooklyn
#  Zip Code: 11205
#  Rating: 3.0
#  Review Count: 18
#
#  Store Name: Manhattanville Coffee
#  Categories: ['Coffee & Tea']
#  Latitude: 40.671649
#  Longitude: -73.952914
#  City: Brooklyn
#  Zip Code: 11216
#  Rating: 4.0
#  Review Count: 72
#
#  Store Name: Gran Caffe' De Martini
#  Categories: ['Coffee & Tea', 'Chocolatiers & Shops', 'Desserts']
#  Latitude: 40.679033
#  Longitude: -73.968045
#  City: Brooklyn
#  Zip Code: 11238
#  Rating: 5.0
#  Review Count: 7
#
#  Store Name: Café Regular du Nord
#  Categories: ['Coffee & Tea']
#  Latitude: 40.6750793457031
#  Longitude: -73.9755477905273
#  City: Brooklyn
#  Zip Code: 11217
#  Rating: 4.0
#  Review Count: 136
